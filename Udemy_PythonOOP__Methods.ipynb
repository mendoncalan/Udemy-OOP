# %% [markdown]
# <a href="https://colab.research.google.com/github/mendoncalan/Udemy-OOP/blob/main/Udemy_PythonOOP__Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Method**
# A function associated to an object of the class or to the class itself is called a method.
#
# The Methods defined in a class determine the behavior of the objects created from the class and how they can interact with their state.
#
# A method is a function that belongs to an object,
#
# Calling a method is similar to calling a function. here we are asking the code to execute it functionality.
#
# Method names usually include verbs since they represents actions.
#
# There are 3 main type of methods
#
# 1. Instance :Mds that belong to a specific object. Because they have access to the state of the object that calls them(self).
#
#
# Syntax:
#
#         class My_class:
#
#           #Class Attribute
#
#           #__init__()
#
#           def method_nam(self, param1 , param2, ...):
#             # code
#
#
#
#
# 2. Class
# 3. Static
#
# Method will handle the behaviour of the call

# %%
#Method of the class

class Circle:
  def __init__(self, radius):
    self.radius = radius
  # method
  def find_diameter(self):
    print(f"Diameter :{self.radius*2}")

my_circle= Circle(2)
my_circle.find_diameter()

class Backpack:
  def __init__(self):
    self._items = []

  @property
  def items(self):
    return self._items
  def add_item(self,  item):
    if isinstance(item, str):
      self._items.append(item)
    else:
      print("Please enter the valid method")
  def remove_item(self, item):
    if isinstance(item, str) and item in self._items:
      self._items.remove(item)
      print(f"Item was remove {item}")
    else:
      print("Enter is not present in the list so could not be removed")
  def has_item(self, item):
    if isinstance(item, str) and item in self._items:
      print("Item is present in the list")
    else:
      print("Item is not present in the list")
# Out:
# Diameter :4
